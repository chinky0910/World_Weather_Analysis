# %%
# import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
        #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | saskylakh
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | manaure
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | port shepstone
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | pedro juan caballero
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 1 | uvira
# Processing Record 15 of Set 1 | takoradi
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | dingle
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | roald
# Processing Record 23 of Set 1 | port hawkesbury
# Processing Record 24 of Set 1 | kihei
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | tyup
# Processing Record 28 of Set 1 | fuling
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | katsuura
# Processing Record 33 of Set 1 | makung
# City not found. Skipping...
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | pisco
# Processing Record 37 of Set 1 | xichang
# Processing Record 38 of Set 1 | fare
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | vagur
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | cabedelo
# Processing Record 43 of Set 1 | ostrovnoy
# Processing Record 44 of Set 1 | westport
# Processing Record 45 of Set 1 | shulin
# Processing Record 46 of Set 1 | bajil
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | estelle
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | portland
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | tuatapere
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | campina verde
# Processing Record 7 of Set 2 | sitka
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | lompoc
# Processing Record 10 of Set 2 | alta floresta
# Processing Record 11 of Set 2 | luanda
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | okhotsk
# Processing Record 14 of Set 2 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 2 | baijiantan
# Processing Record 16 of Set 2 | aksu
# Processing Record 17 of Set 2 | meulaboh
# Processing Record 18 of Set 2 | salalah
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 2 | broken hill
# Processing Record 22 of Set 2 | vanimo
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | atar
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | paamiut
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | tessalit
# Processing Record 34 of Set 2 | boone
# Processing Record 35 of Set 2 | sur
# Processing Record 36 of Set 2 | hervey bay
# Processing Record 37 of Set 2 | la sarre
# Processing Record 38 of Set 2 | iquique
# Processing Record 39 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 40 of Set 2 | sheridan
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | vila
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | kribi
# Processing Record 47 of Set 2 | avera
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | eureka
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 3 | okitipupa
# Processing Record 5 of Set 3 | sao joao da barra
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | morki
# Processing Record 8 of Set 3 | gore
# Processing Record 9 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 3 | ondangwa
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | inuvik
# Processing Record 14 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 15 of Set 3 | filadelfia
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | taltal
# Processing Record 18 of Set 3 | riyadh
# Processing Record 19 of Set 3 | parker
# Processing Record 20 of Set 3 | vardo
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | kidal
# Processing Record 26 of Set 3 | tanabe
# Processing Record 27 of Set 3 | margate
# Processing Record 28 of Set 3 | abu dhabi
# Processing Record 29 of Set 3 | libreville
# Processing Record 30 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 3 | lagoa
# Processing Record 32 of Set 3 | itarema
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | vila velha
# Processing Record 35 of Set 3 | fukue
# Processing Record 36 of Set 3 | korla
# Processing Record 37 of Set 3 | bom jardim
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | tomohon
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | mbini
# Processing Record 42 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | ahipara
# Processing Record 45 of Set 3 | clarence town
# Processing Record 46 of Set 3 | chenghai
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | alpena
# Processing Record 49 of Set 3 | sambava
# Processing Record 50 of Set 3 | konevo
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | laguna
# Processing Record 3 of Set 4 | veracruz
# Processing Record 4 of Set 4 | bulgan
# Processing Record 5 of Set 4 | hilo
# Processing Record 6 of Set 4 | port hardy
# Processing Record 7 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | belmonte
# Processing Record 10 of Set 4 | islamkot
# Processing Record 11 of Set 4 | presidente medici
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | burnie
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | linqing
# Processing Record 16 of Set 4 | saiha
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | sorland
# Processing Record 20 of Set 4 | pringsewu
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | bereznik
# Processing Record 23 of Set 4 | zhigansk
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | gat
# Processing Record 27 of Set 4 | verkhnevilyuysk
# Processing Record 28 of Set 4 | tabou
# Processing Record 29 of Set 4 | halifax
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | maku
# Processing Record 32 of Set 4 | port alfred
# Processing Record 33 of Set 4 | kabelvag
# Processing Record 34 of Set 4 | ilulissat
# Processing Record 35 of Set 4 | codrington
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | juegang
# Processing Record 38 of Set 4 | corrente
# Processing Record 39 of Set 4 | tahta
# Processing Record 40 of Set 4 | bethel
# Processing Record 41 of Set 4 | bathsheba
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | maneadero
# Processing Record 44 of Set 4 | aketi
# Processing Record 45 of Set 4 | yuzhou
# Processing Record 46 of Set 4 | hermanus
# Processing Record 47 of Set 4 | kondinskoye
# Processing Record 48 of Set 4 | pangai
# Processing Record 49 of Set 4 | tura
# Processing Record 50 of Set 4 | premia de mar
# Processing Record 1 of Set 5 | mackay
# Processing Record 2 of Set 5 | maldonado
# Processing Record 3 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 5 | tsaratanana
# Processing Record 5 of Set 5 | bhera
# Processing Record 6 of Set 5 | moree
# Processing Record 7 of Set 5 | grimari
# City not found. Skipping...
# Processing Record 8 of Set 5 | sisimiut
# Processing Record 9 of Set 5 | batsfjord
# Processing Record 10 of Set 5 | burhaniye
# Processing Record 11 of Set 5 | matay
# Processing Record 12 of Set 5 | sumter
# Processing Record 13 of Set 5 | lorengau
# Processing Record 14 of Set 5 | caravelas
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | kloulklubed
# Processing Record 17 of Set 5 | hauterive
# Processing Record 18 of Set 5 | londoko
# Processing Record 19 of Set 5 | la ronge
# Processing Record 20 of Set 5 | macamic
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 5 | korba
# Processing Record 24 of Set 5 | harper
# Processing Record 25 of Set 5 | henties bay
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | douglas
# Processing Record 29 of Set 5 | pundaguitan
# Processing Record 30 of Set 5 | port lincoln
# Processing Record 31 of Set 5 | dikson
# Processing Record 32 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | oyama
# Processing Record 35 of Set 5 | omboue
# Processing Record 36 of Set 5 | kollam
# Processing Record 37 of Set 5 | flin flon
# Processing Record 38 of Set 5 | kashi
# Processing Record 39 of Set 5 | tsienyane
# City not found. Skipping...
# Processing Record 40 of Set 5 | kulotino
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | benin
# Processing Record 46 of Set 5 | senneterre
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | provideniya
# Processing Record 49 of Set 5 | asau
# Processing Record 50 of Set 5 | chapais
# Processing Record 1 of Set 6 | leningradskiy
# Processing Record 2 of Set 6 | marsh harbour
# Processing Record 3 of Set 6 | vila do maio
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | praia da vitoria
# Processing Record 6 of Set 6 | natchez
# Processing Record 7 of Set 6 | winona
# Processing Record 8 of Set 6 | karatau
# Processing Record 9 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 10 of Set 6 | tinskoy
# Processing Record 11 of Set 6 | puerto escondido
# Processing Record 12 of Set 6 | skjervoy
# Processing Record 13 of Set 6 | jiwani
# Processing Record 14 of Set 6 | yulara
# Processing Record 15 of Set 6 | gazanjyk
# Processing Record 16 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 6 | chara
# Processing Record 18 of Set 6 | norilsk
# Processing Record 19 of Set 6 | taoudenni
# Processing Record 20 of Set 6 | suraabad
# Processing Record 21 of Set 6 | anaco
# Processing Record 22 of Set 6 | sayyan
# Processing Record 23 of Set 6 | prince rupert
# Processing Record 24 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 6 | barao de melgaco
# Processing Record 26 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 6 | domoni
# Processing Record 28 of Set 6 | vao
# Processing Record 29 of Set 6 | castro
# Processing Record 30 of Set 6 | hillsborough
# Processing Record 31 of Set 6 | temiscaming
# Processing Record 32 of Set 6 | bankura
# Processing Record 33 of Set 6 | okha
# Processing Record 34 of Set 6 | pingzhuang
# Processing Record 35 of Set 6 | midland
# Processing Record 36 of Set 6 | husavik
# Processing Record 37 of Set 6 | dire
# Processing Record 38 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 39 of Set 6 | labuan
# Processing Record 40 of Set 6 | florence
# Processing Record 41 of Set 6 | guane
# Processing Record 42 of Set 6 | saint-pierre
# Processing Record 43 of Set 6 | alvorada
# Processing Record 44 of Set 6 | winsum
# Processing Record 45 of Set 6 | tautira
# Processing Record 46 of Set 6 | hals
# Processing Record 47 of Set 6 | pandi
# Processing Record 48 of Set 6 | taber
# Processing Record 49 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 6 | new norfolk
# Processing Record 1 of Set 7 | bambanglipuro
# Processing Record 2 of Set 7 | fomboni
# Processing Record 3 of Set 7 | pran buri
# Processing Record 4 of Set 7 | vestmannaeyjar
# Processing Record 5 of Set 7 | thompson
# Processing Record 6 of Set 7 | middle island
# Processing Record 7 of Set 7 | ola
# Processing Record 8 of Set 7 | port moresby
# Processing Record 9 of Set 7 | pyaozerskiy
# Processing Record 10 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 7 | el badari
# City not found. Skipping...
# Processing Record 12 of Set 7 | praya
# Processing Record 13 of Set 7 | lata
# Processing Record 14 of Set 7 | ahuimanu
# Processing Record 15 of Set 7 | pangnirtung
# Processing Record 16 of Set 7 | lazaro cardenas
# Processing Record 17 of Set 7 | esperance
# Processing Record 18 of Set 7 | yar-sale
# Processing Record 19 of Set 7 | wanning
# Processing Record 20 of Set 7 | clyde river
# Processing Record 21 of Set 7 | augusto correa
# Processing Record 22 of Set 7 | jeremie
# Processing Record 23 of Set 7 | polyarnyy
# Processing Record 24 of Set 7 | sfantu gheorghe
# Processing Record 25 of Set 7 | nizhneudinsk
# Processing Record 26 of Set 7 | veraval
# Processing Record 27 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 7 | orlik
# Processing Record 29 of Set 7 | mahina
# Processing Record 30 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 7 | sept-iles
# Processing Record 32 of Set 7 | road town
# Processing Record 33 of Set 7 | buala
# Processing Record 34 of Set 7 | yasenskaya
# Processing Record 35 of Set 7 | las palmas
# Processing Record 36 of Set 7 | mount gambier
# Processing Record 37 of Set 7 | qena
# Processing Record 38 of Set 7 | ajdabiya
# Processing Record 39 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 7 | narsaq
# Processing Record 41 of Set 7 | niceville
# Processing Record 42 of Set 7 | zeya
# Processing Record 43 of Set 7 | key largo
# Processing Record 44 of Set 7 | touros
# Processing Record 45 of Set 7 | quime
# Processing Record 46 of Set 7 | revelstoke
# Processing Record 47 of Set 7 | bubaque
# Processing Record 48 of Set 7 | cidreira
# Processing Record 49 of Set 7 | saint anthony
# Processing Record 50 of Set 7 | el wasta
# City not found. Skipping...
# Processing Record 1 of Set 8 | belaya gora
# Processing Record 2 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 8 | acapulco
# Processing Record 4 of Set 8 | amapa
# Processing Record 5 of Set 8 | mananara
# Processing Record 6 of Set 8 | kon tum
# Processing Record 7 of Set 8 | sakakah
# Processing Record 8 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 8 | mangrol
# Processing Record 10 of Set 8 | jasper
# Processing Record 11 of Set 8 | dunmore east
# Processing Record 12 of Set 8 | sobolevo
# Processing Record 13 of Set 8 | majene
# Processing Record 14 of Set 8 | blagoyevo
# Processing Record 15 of Set 8 | bom jesus
# Processing Record 16 of Set 8 | chadan
# Processing Record 17 of Set 8 | kahului
# Processing Record 18 of Set 8 | pandan
# Processing Record 19 of Set 8 | tukrah
# Processing Record 20 of Set 8 | manggar
# Processing Record 21 of Set 8 | yerbogachen
# Processing Record 22 of Set 8 | de pere
# Processing Record 23 of Set 8 | miramar
# Processing Record 24 of Set 8 | kula
# Processing Record 25 of Set 8 | tokzar
# City not found. Skipping...
# Processing Record 26 of Set 8 | acajutla
# Processing Record 27 of Set 8 | tsiroanomandidy
# Processing Record 28 of Set 8 | tondano
# Processing Record 29 of Set 8 | lalibela
# Processing Record 30 of Set 8 | angra
# City not found. Skipping...
# Processing Record 31 of Set 8 | tongling
# Processing Record 32 of Set 8 | dukat
# Processing Record 33 of Set 8 | arzgir
# Processing Record 34 of Set 8 | ewa beach
# Processing Record 35 of Set 8 | nishihara
# Processing Record 36 of Set 8 | yinchuan
# Processing Record 37 of Set 8 | kungurtug
# Processing Record 38 of Set 8 | opuwo
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | cibinong
# Processing Record 42 of Set 8 | oranjemund
# Processing Record 43 of Set 8 | keetmanshoop
# Processing Record 44 of Set 8 | coihaique
# Processing Record 45 of Set 8 | guerrero
# Processing Record 46 of Set 8 | manokwari
# Processing Record 47 of Set 8 | tailai
# Processing Record 48 of Set 8 | hammerfest
# Processing Record 49 of Set 8 | bud
# Processing Record 50 of Set 8 | sirsi
# Processing Record 1 of Set 9 | kaduqli
# Processing Record 2 of Set 9 | aykino
# Processing Record 3 of Set 9 | jiuquan
# Processing Record 4 of Set 9 | kifri
# Processing Record 5 of Set 9 | sturgeon falls
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | shingu
# Processing Record 8 of Set 9 | the valley
# Processing Record 9 of Set 9 | tarauaca
# Processing Record 10 of Set 9 | synya
# Processing Record 11 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 12 of Set 9 | padang
# Processing Record 13 of Set 9 | aksay
# Processing Record 14 of Set 9 | mazagao
# Processing Record 15 of Set 9 | zyryanka
# Processing Record 16 of Set 9 | almansa
# Processing Record 17 of Set 9 | coahuayana
# Processing Record 18 of Set 9 | namibe
# Processing Record 19 of Set 9 | bousso
# Processing Record 20 of Set 9 | santiago del estero
# Processing Record 21 of Set 9 | mugango
# Processing Record 22 of Set 9 | maniitsoq
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | fort saint james
# Processing Record 25 of Set 9 | albanel
# Processing Record 26 of Set 9 | ayan
# Processing Record 27 of Set 9 | peterhead
# Processing Record 28 of Set 9 | geraldton
# Processing Record 29 of Set 9 | roebourne
# Processing Record 30 of Set 9 | san policarpo
# Processing Record 31 of Set 9 | anju
# Processing Record 32 of Set 9 | limon
# Processing Record 33 of Set 9 | marsa matruh
# Processing Record 34 of Set 9 | nanyang
# Processing Record 35 of Set 9 | soskovo
# Processing Record 36 of Set 9 | malabor
# Processing Record 37 of Set 9 | new waterford
# Processing Record 38 of Set 9 | quang ngai
# Processing Record 39 of Set 9 | itaituba
# Processing Record 40 of Set 9 | tezu
# Processing Record 41 of Set 9 | pacific grove
# Processing Record 42 of Set 9 | quincy
# Processing Record 43 of Set 9 | honningsvag
# Processing Record 44 of Set 9 | camana
# Processing Record 45 of Set 9 | orel-izumrud
# Processing Record 46 of Set 9 | loknya
# Processing Record 47 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 9 | mgandu
# Processing Record 49 of Set 9 | karratha
# Processing Record 50 of Set 9 | bilibino
# Processing Record 1 of Set 10 | makakilo city
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 10 | tupancireta
# Processing Record 5 of Set 10 | beloha
# Processing Record 6 of Set 10 | spirit river
# Processing Record 7 of Set 10 | beringovskiy
# Processing Record 8 of Set 10 | benguela
# Processing Record 9 of Set 10 | lasa
# Processing Record 10 of Set 10 | dauphin
# Processing Record 11 of Set 10 | sundsvall
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | khuzdar
# Processing Record 14 of Set 10 | birao
# Processing Record 15 of Set 10 | hongjiang
# Processing Record 16 of Set 10 | erzin
# Processing Record 17 of Set 10 | labuhan
# Processing Record 18 of Set 10 | madaoua
# Processing Record 19 of Set 10 | santa isabel do rio negro
# Processing Record 20 of Set 10 | comarapa
# Processing Record 21 of Set 10 | lufkin
# Processing Record 22 of Set 10 | salinopolis
# Processing Record 23 of Set 10 | tehri
# Processing Record 24 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 10 | khani
# Processing Record 28 of Set 10 | lavrentiya
# Processing Record 29 of Set 10 | storforshei
# Processing Record 30 of Set 10 | peniche
# Processing Record 31 of Set 10 | matara
# Processing Record 32 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 10 | ano mera
# Processing Record 34 of Set 10 | la romana
# Processing Record 35 of Set 10 | blackwater
# Processing Record 36 of Set 10 | sistranda
# Processing Record 37 of Set 10 | luderitz
# Processing Record 38 of Set 10 | corinto
# Processing Record 39 of Set 10 | sawakin
# Processing Record 40 of Set 10 | udachnyy
# Processing Record 41 of Set 10 | warkworth
# Processing Record 42 of Set 10 | denpasar
# Processing Record 43 of Set 10 | kudahuvadhoo
# Processing Record 44 of Set 10 | lonavale
# Processing Record 45 of Set 10 | biltine
# Processing Record 46 of Set 10 | viedma
# Processing Record 47 of Set 10 | ayna
# Processing Record 48 of Set 10 | boueni
# Processing Record 49 of Set 10 | ancud
# Processing Record 50 of Set 10 | dwarka
# Processing Record 1 of Set 11 | suseni
# Processing Record 2 of Set 11 | pacifica
# Processing Record 3 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 11 | berbera
# Processing Record 5 of Set 11 | antofagasta
# Processing Record 6 of Set 11 | kattivakkam
# Processing Record 7 of Set 11 | camabatela
# Processing Record 8 of Set 11 | san quintin
# Processing Record 9 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 11 | umm lajj
# Processing Record 11 of Set 11 | kavieng
# Processing Record 12 of Set 11 | maragogi
# Processing Record 13 of Set 11 | dalby
# Processing Record 14 of Set 11 | zanatepec
# City not found. Skipping...
# Processing Record 15 of Set 11 | kemijarvi
# Processing Record 16 of Set 11 | hualmay
# Processing Record 17 of Set 11 | tokur
# Processing Record 18 of Set 11 | haines junction
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | vadso
# Processing Record 21 of Set 11 | aykhal
# Processing Record 22 of Set 11 | kukshi
# Processing Record 23 of Set 11 | jinchang
# Processing Record 24 of Set 11 | san patricio
# Processing Record 25 of Set 11 | namatanai
# Processing Record 26 of Set 11 | pinotepa nacional
# Processing Record 27 of Set 11 | fereydunshahr
# Processing Record 28 of Set 11 | oxapampa
# Processing Record 29 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 11 | lodja
# Processing Record 31 of Set 11 | ascension
# Processing Record 32 of Set 11 | hami
# Processing Record 33 of Set 11 | tungor
# Processing Record 34 of Set 11 | tashtagol
# Processing Record 35 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 11 | barcelona
# Processing Record 37 of Set 11 | mattru
# Processing Record 38 of Set 11 | mantua
# Processing Record 39 of Set 11 | terre haute
# Processing Record 40 of Set 11 | sibolga
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | biu
# Processing Record 43 of Set 11 | marzuq
# Processing Record 44 of Set 11 | araouane
# Processing Record 45 of Set 11 | nemuro
# Processing Record 46 of Set 11 | bandarbeyla
# Processing Record 47 of Set 11 | shagamu
# Processing Record 48 of Set 11 | songea
# Processing Record 49 of Set 11 | ouallam
# Processing Record 50 of Set 11 | manzanillo
# Processing Record 1 of Set 12 | bowen
# Processing Record 2 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 12 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 4 of Set 12 | katobu
# Processing Record 5 of Set 12 | erenhot
# Processing Record 6 of Set 12 | coffs harbour
# Processing Record 7 of Set 12 | nueva loja
# Processing Record 8 of Set 12 | pendleton
# Processing Record 9 of Set 12 | cooma
# Processing Record 10 of Set 12 | mumford
# Processing Record 11 of Set 12 | coalcoman
# City not found. Skipping...
# Processing Record 12 of Set 12 | himora
# City not found. Skipping...
# Processing Record 13 of Set 12 | olafsvik
# Processing Record 14 of Set 12 | verkhoyansk
# Processing Record 15 of Set 12 | hasaki
# Processing Record 16 of Set 12 | datong
# Processing Record 17 of Set 12 | sainte-rose
# Processing Record 18 of Set 12 | snyder
# Processing Record 19 of Set 12 | calama
# Processing Record 20 of Set 12 | port hedland
# Processing Record 21 of Set 12 | issenye
# Processing Record 22 of Set 12 | nanhai
# Processing Record 23 of Set 12 | havelock
# Processing Record 24 of Set 12 | pavlovskaya sloboda
# Processing Record 25 of Set 12 | pelotas
# Processing Record 26 of Set 12 | daru
# Processing Record 27 of Set 12 | yei
# Processing Record 28 of Set 12 | touba
# Processing Record 29 of Set 12 | batagay-alyta
# Processing Record 30 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 12 | valleyview
# Processing Record 32 of Set 12 | gushikawa
# Processing Record 33 of Set 12 | banamba
# Processing Record 34 of Set 12 | kieta
# Processing Record 35 of Set 12 | sterling
# Processing Record 36 of Set 12 | ossora
# Processing Record 37 of Set 12 | katangli
# Processing Record 38 of Set 12 | stromness
# Processing Record 39 of Set 12 | ucluelet
# Processing Record 40 of Set 12 | adrar
# Processing Record 41 of Set 12 | sangamner
# Processing Record 42 of Set 12 | tonbridge
# Processing Record 43 of Set 12 | jati
# Processing Record 44 of Set 12 | champerico
# Processing Record 45 of Set 12 | kiunga
# Processing Record 46 of Set 12 | srednekolymsk
# Processing Record 47 of Set 12 | college
# Processing Record 48 of Set 12 | kinablangan
# Processing Record 49 of Set 12 | coyoles
# Processing Record 50 of Set 12 | kirkuk
# Processing Record 1 of Set 13 | mayo
# Processing Record 2 of Set 13 | shafter
# Processing Record 3 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 4 of Set 13 | kpandae
# Processing Record 5 of Set 13 | qiongshan
# Processing Record 6 of Set 13 | fiche
# Processing Record 7 of Set 13 | port macquarie
# Processing Record 8 of Set 13 | tiarei
# Processing Record 9 of Set 13 | charlestown
# Processing Record 10 of Set 13 | yeppoon
# Processing Record 11 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 12 of Set 13 | kenai
# Processing Record 13 of Set 13 | gamba
# Processing Record 14 of Set 13 | tomatlan
# Processing Record 15 of Set 13 | pindiga
# Processing Record 16 of Set 13 | monte alegre
# Processing Record 17 of Set 13 | trincomalee
# Processing Record 18 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 13 | kemin
# Processing Record 20 of Set 13 | ponta delgada
# Processing Record 21 of Set 13 | nizhniy kuranakh
# Processing Record 22 of Set 13 | konakovo
# Processing Record 23 of Set 13 | mandalgovi
# Processing Record 24 of Set 13 | selikhino
# Processing Record 25 of Set 13 | svetlyy
# Processing Record 26 of Set 13 | purranque
# Processing Record 27 of Set 13 | shu
# Processing Record 28 of Set 13 | ulaangom
# Processing Record 29 of Set 13 | marsabit
# Processing Record 30 of Set 13 | poya
# Processing Record 31 of Set 13 | lamu
# Processing Record 32 of Set 13 | ust-maya
# Processing Record 33 of Set 13 | rovaniemi
# Processing Record 34 of Set 13 | umm kaddadah
# Processing Record 35 of Set 13 | caldwell
# Processing Record 36 of Set 13 | hofn
# Processing Record 37 of Set 13 | gweta
# Processing Record 38 of Set 13 | wasilla
# Processing Record 39 of Set 13 | proletariy
# Processing Record 40 of Set 13 | saint-denis
# Processing Record 41 of Set 13 | kralendijk
# Processing Record 42 of Set 13 | sangueya
# Processing Record 43 of Set 13 | derzhavinsk
# Processing Record 44 of Set 13 | taylorville
# Processing Record 45 of Set 13 | guerrero negro
# Processing Record 46 of Set 13 | gravdal
# Processing Record 47 of Set 13 | atasu
# Processing Record 48 of Set 13 | burica
# City not found. Skipping...
# Processing Record 49 of Set 13 | prainha
# Processing Record 50 of Set 13 | san cristobal
# Processing Record 1 of Set 14 | yumen
# Processing Record 2 of Set 14 | siilinjarvi
# Processing Record 3 of Set 14 | aqtobe
# Processing Record 4 of Set 14 | mutis
# Processing Record 5 of Set 14 | huntsville
# Processing Record 6 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 14 | yuncheng
# Processing Record 8 of Set 14 | suratgarh
# Processing Record 9 of Set 14 | trinidad
# Processing Record 10 of Set 14 | salinas
# Processing Record 11 of Set 14 | safford
# Processing Record 12 of Set 14 | assai
# Processing Record 13 of Set 14 | bandar
# Processing Record 14 of Set 14 | sagua la grande
# Processing Record 15 of Set 14 | eyl
# Processing Record 16 of Set 14 | seoul
# Processing Record 17 of Set 14 | high level
# Processing Record 18 of Set 14 | altay
# Processing Record 19 of Set 14 | nisia floresta
# Processing Record 20 of Set 14 | santa fe
# Processing Record 21 of Set 14 | havoysund
# Processing Record 22 of Set 14 | chulym
# Processing Record 23 of Set 14 | lashio
# Processing Record 24 of Set 14 | kununurra
# Processing Record 25 of Set 14 | kushima
# Processing Record 26 of Set 14 | arman
# Processing Record 27 of Set 14 | kilindoni
# Processing Record 28 of Set 14 | rassvet
# Processing Record 29 of Set 14 | buckeye
# Processing Record 30 of Set 14 | aragarcas
# Processing Record 31 of Set 14 | podyuga
# Processing Record 32 of Set 14 | kalianget
# Processing Record 33 of Set 14 | riviere-au-renard
# Processing Record 34 of Set 14 | biak
# Processing Record 35 of Set 14 | pochutla
# Processing Record 36 of Set 14 | suchiapa
# Processing Record 37 of Set 14 | bagrami
# Processing Record 38 of Set 14 | zhaocheng
# City not found. Skipping...
# Processing Record 39 of Set 14 | tonneins
# Processing Record 40 of Set 14 | carballo
# Processing Record 41 of Set 14 | marseille
# Processing Record 42 of Set 14 | joetsu
# Processing Record 43 of Set 14 | tilzapotla
# Processing Record 44 of Set 14 | general pico
# Processing Record 45 of Set 14 | kazachinskoye
# Processing Record 46 of Set 14 | oskarshamn
# Processing Record 47 of Set 14 | sioux lookout
# Processing Record 48 of Set 14 | shahrud
# Processing Record 49 of Set 14 | jiaohe
# Processing Record 50 of Set 14 | harnosand
# Processing Record 1 of Set 15 | santa cruz
# Processing Record 2 of Set 15 | muhlhausen
# Processing Record 3 of Set 15 | lubumbashi
# Processing Record 4 of Set 15 | te anau
# Processing Record 5 of Set 15 | guozhen
# Processing Record 6 of Set 15 | vysha
# Processing Record 7 of Set 15 | amahai
# Processing Record 8 of Set 15 | joao pinheiro
# Processing Record 9 of Set 15 | walvis bay
# Processing Record 10 of Set 15 | nabire
# Processing Record 11 of Set 15 | kouroussa
# Processing Record 12 of Set 15 | dhidhdhoo
# Processing Record 13 of Set 15 | maebaru
# Processing Record 14 of Set 15 | borovoy
# Processing Record 15 of Set 15 | metro
# Processing Record 16 of Set 15 | kamaishi
# Processing Record 17 of Set 15 | songjianghe
# Processing Record 18 of Set 15 | merauke
# Processing Record 19 of Set 15 | bangangte
# Processing Record 20 of Set 15 | lampang
# Processing Record 21 of Set 15 | savannah bight
# Processing Record 22 of Set 15 | qandala
# Processing Record 23 of Set 15 | yefimovskiy
# City not found. Skipping...
# Processing Record 24 of Set 15 | upington
# Processing Record 25 of Set 15 | popondetta
# Processing Record 26 of Set 15 | erzincan
# Processing Record 27 of Set 15 | khasan
# Processing Record 28 of Set 15 | pishin
# Processing Record 29 of Set 15 | altar
# Processing Record 30 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 15 | tuensang
# Processing Record 32 of Set 15 | zabaykalsk
# Processing Record 33 of Set 15 | tianpeng
# Processing Record 34 of Set 15 | manyana
# Processing Record 35 of Set 15 | wilmington island
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 670

# %%
#Convert the array of dictionaries to a panda dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Busselton      AU -33.6500  115.3333     66.04        71           0
# 1         Ushuaia      AR -54.8000  -68.3000     38.86        81          75
# 2       Saskylakh      RU  71.9167  114.0833    -17.90        89          46
# 3      Georgetown      MY   5.4112  100.3354     79.90        90          40
# 4         Manaure      CO  11.7751  -72.4445     89.71        59          10
# 5      Bredasdorp      ZA -34.5322   20.0403     65.52        72          97
# 6  Port Shepstone      ZA -30.7414   30.4550     74.75        80         100
# 7           Kapaa      US  22.0752 -159.3190     82.38        60          40
# 8    Norman Wells      CA  65.2820 -126.8329     -7.56        64         100
# 9       Carnarvon      AU -24.8667  113.6333     77.07        88           3
#
#    Wind Speed Current Description
# 0       12.26           clear sky
# 1       16.11       broken clouds
# 2        3.00    scattered clouds
# 3        3.44    scattered clouds
# 4       22.79           clear sky
# 5        8.05     overcast clouds
# 6       11.72     overcast clouds
# 7       16.11    scattered clouds
# 8        5.75     overcast clouds
# 9        0.00           clear sky

# %%
#Export the dataframe to csv file.
city_data_df.to_csv("WeatherPy_Database.csv")
